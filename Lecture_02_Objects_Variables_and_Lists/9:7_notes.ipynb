# %%
print(2**3)
# Out:
# 8

# %%
print(40/6)
# Out:
# 6.666666666666667

# %%
print(40//6)
# Out:
# 6

# %%
print(40%6)
# Out:
# 4

# %%
print(log2(8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(log2(8))
#
# NameError: name 'log2' is not defined

# %%
import math

# %%
print(math.log2(8))
# Out:
# 3.0

# %%
import statistics
print(statistics.mean({1,5,8,9,14}))
# Out:
# 7.4

# %%
import statistics as stats
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(stats.mean({1,2,3,4,5}))
# Out:
# 3

# %%
carfeatures=pd.read_csv

# %%
carfeatures = pd.read_csv('data/features.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 carfeatures = pd.read_csv('data/features.csv')
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
carfeatures = pd.read_csv('data/features.csv')
display(carfeatures)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 carfeatures = pd.read_csv('data/features.csv')
#       2 display(carfeatures)
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
carfeatures = pd.read_csv('data/features.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 carfeatures = pd.read_csv('data/features.csv')
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import os
print(os.getcwd())     
print(os.listdir())
# Out:
# /Users/wangyihan/Desktop/Emory Courses/2026 Fall/Datasci 185/GitHub/datasci185fall2026
# ['.DS_Store', 'LICENSE', 'Lecture_00_IntroAndSyllabus', 'Lab_02', 'Lecture_01', 'README.md', '.gitignore', 'computing_setup', '_qtm151_spring2025_tutorials', '.git', '.vscode', 'Lecture_02_Objects_Variables_and_Lists']

# %%
carfeatures = pd.read_csv('Lecture_01/data/features.csv')

# %%
display(carfeatures)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle id
# 0    18.0          8           307        130    3504          12.0  C-1689780
# 1    15.0          8           350        165    3693          11.5  B-1689791
# 2    18.0          8           318        150    3436          11.0  P-1689802
# 3    16.0          8           304        150    3433          12.0  A-1689813
# 4    17.0          8           302        140    3449          10.5  F-1689824
# ..    ...        ...           ...        ...     ...           ...        ...
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 395  32.0          4           135         84    2295          11.6  D-1694125
# 396  28.0          4           120         79    2625          18.6  F-1694136
# 397  31.0          4           119         82    2720          19.4  C-1694147
#
# [398 rows x 7 columns]

# %%
display(carfeatures['cylinders'])
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 393    4
# 394    4
# 395    4
# 396    4
# 397    4
# Name: cylinders, Length: 398, dtype: int64

# %%
table = pd.crosstab(index = carfeatures['cylinders'],columns = "count")
display(table)
# Out:
# col_0      count
# cylinders
# 3              4
# 4            204
# 5              3
# 6             84
# 8            103

# %%
table=pd.crosstab(carfeatures['cylinders'],'count')

# %%
display(table)
# Out:
# col_0      count
# cylinders
# 3              4
# 4            204
# 5              3
# 6             84
# 8            103

# %%
table_2=pd.crosstab(carfeatures['cylinders'],carfeatures['mpg'])
display(table)
# Out:
# col_0      count
# cylinders
# 3              4
# 4            204
# 5              3
# 6             84
# 8            103

# %%
carfeatures.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
round(carfeatures.describe(),2)
# Out:
#           mpg  cylinders  displacement   weight  acceleration
# count  398.00     398.00        398.00   398.00        398.00
# mean    23.51       5.45        193.43  2970.42         15.57
# std      7.82       1.70        104.27   846.84          2.76
# min      9.00       3.00         68.00  1613.00          8.00
# 25%     17.50       4.00        104.25  2223.75         13.82
# 50%     23.00       4.00        148.50  2803.50         15.50
# 75%     29.00       8.00        262.00  3608.00         17.18
# max     46.60       8.00        455.00  5140.00         24.80

# %%
carfeatures.describe(percentiles=[0.33,0.66])
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 33%     19.000000    4.000000    116.030000  2391.040000     14.500000
# 66%     26.600000    6.000000    232.000000  3278.080000     16.500000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
plt.scatter(x=carfeatures['weight'],y=carfeatures['mpg'])
plt.xlabel('weight')
plt.ylabel('mpg')
plt.title('cool plot')
# Out:
# Text(0.5, 1.0, 'cool plot')

# %%
plt.xlabel('weight')
# Out:
# Text(0.5, 0, 'weight')

# %%
plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
plt.xlabel("Weight")
plt.ylabel("MPG")
plt.title("cool plot")

plt.scatter(x = carfeatures['weight'], y = carfeatures['acceleration'])
plt.xlabel("Weight")
plt.ylabel("acc")
plt.title("cool plot")
plt.show()

# %%
type(3)
# Out:
# int

# %%
type(2/3)
# Out:
# float

# %%
type('nihao shijie')
# Out:
# str

# %%
print(type(3))
print(type(3.25))
print(type("Hello World!"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print("In today's lecture we learned that \"classes\" and \"types\" are essentially synonymous.")
# Out:
# In today's lecture we learned that "classes" and "types" are essentially synonymous.

# %%
print("In today's lecture we learned that \"classes\" and \"types\" are essential")
# Out:
# In today's lecture we learned that "classes" and "types" are essential

# %%
print('In today\'s lecture we learned that "classes" and "types" are essential')
# Out:
# In today's lecture we learned that "classes" and "types" are essential

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
x=3
x=4

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
record_price=32.99
FC_sales_tax=0.089
D_sales_tax=0.08
D_price=record_price+record_price*D_sales_tax
print(D_price)
# Out:
# 35.629200000000004
